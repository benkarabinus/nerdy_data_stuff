# %% [markdown]
# # **Week 1 Asynch Ben Karabinus**
# ## *Using markdown to create documentation inside of Jupyter Notebooks is awesome!*

# %% [markdown]
# # Let's demonstrate some basic Latex syntax and Python code
# 1. We'll start by writing out a formula for taking the sum of all integers between 1 and 10 in Latex.
# 1. Then we will implement the formula using Python

# %% [markdown]
# $\displaystyle\sum_{n=1}^{10}i$

# %%
# Python implementation
result = 0
for i in range(1, 11):
    result += i
print(result)
# Out:
# 55

# %% [markdown]
# ## Now Lets Go Over a Few Magic Commands

# %%
# lets time some Python print statements using line magic
# %timeit [print("Hello World") for i in range(11)]
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# ...

# %%
# %%bash
# # Write some bash using cell magic
# for i in {1..5}
# do
#    echo "Hello World"
# done
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
