# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
mpg = sns.load_dataset('mpg')
diamonds = sns.load_dataset('diamonds')
car_crashes = sns.load_dataset('car_crashes')
iris = sns.load_dataset('iris')

# %%
diamonds.color.unique()
# Out:
# ['E', 'I', 'J', 'H', 'F', 'G', 'D']
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
diamonds.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
sns.set_style('darkgrid')

# %%
# Part 1 - Correlation Heatmap
sns.heatmap(mpg.corr(), cmap='coolwarm')
plt.tight_layout()
plt.show()

# %%
# Part 1 - Simple Pairplot
sns.pairplot(mpg)
plt.tight_layout()
plt.show()

# %%
# Part 2
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamondsFiltered = diamonds[(diamonds.color != 'E') & (diamonds.color != 'D') & (diamonds.cut != 'Fair')]

diamondsFiltered.color.unique()
# Out:
# ['I', 'J', 'H', 'F', 'G']
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
diamondsFiltered.cut.unique()
# Out:
# ['Premium', 'Good', 'Very Good', 'Ideal']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
g0 = sns.FacetGrid(diamonds, col='cut', row='color')
g0.map(plt.scatter, 'price', 'carat')
plt.tight_layout()
plt.show()

# %%
# Part 3

sns.lmplot(data=car_crashes, x='speeding', y='total')

# %%
sns.lmplot(data=car_crashes, x='alcohol', y='total')

# %%
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharex=True)
sns.boxplot(data=iris, x='species', y='sepal_length', ax=axes[0, 0])
sns.boxplot(data=iris, x='species', y='sepal_width', ax=axes[0, 1])
sns.boxplot(data=iris, x='species', y='petal_length', ax=axes[1, 0])
sns.boxplot(data=iris, x='species', y='petal_width', ax=axes[1, 1])
#plt.tight_layout()
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>
