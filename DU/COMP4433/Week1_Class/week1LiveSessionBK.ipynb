# %%
import numpy as np
import pandas as pd

# %%
carnegie = pd.read_csv('carnegie2021.csv', encoding = 'ISO-8859-1')
us_censu_regions = pd.read_csv('us_census_regions_divisions.csv')

# %%
carnegie = carnegie[carnegie.'basic2]
# Out:
#       unitid                                               name  \
# 11    488031                         Abraham Lincoln University
# 43    188535                                  Albany Law School
# 137   432348                          Appalachian School of Law
# 185   138929                 Atlanta's John Marshall Law School
# 205   442295                            Ave Maria School of Law
# 378   189501                                Brooklyn Law School
# 431   190682                                 CUNY School of Law
# 478   111391                   California Western School of Law
# 624   451510                           Charleston School of Law
# 1518  242723  Inter American University of Puerto Rico-Schoo...
# 1637  134422                                        Key College
# 1879  369002                        Massachusetts School of Law
# 2021  175281                     Mitchell Hamline School of Law
# 2110  461023                         National Paralegal College
# ...
