# %%
import pandas as pd
from collections import OrderedDict, defaultdict

# %%
fundementals = pd.read_csv('/Users/benkarabinus/Documents/Git/nerdy_data_stuff/DU/COMP4581/Assignment2/fundamentals.csv')
prices = pd.read_csv('/Users/benkarabinus/Documents/Git/nerdy_data_stuff/DU/COMP4581/Assignment2/prices-split-adjusted.csv')
#prices = pd.read_csv('/Users/benkarabinus/Documents/Git/nerdy_data_stuff/DU/COMP4581/Assignment2/prices.csv')
securities = pd.read_csv('/Users/benkarabinus/Documents/Git/nerdy_data_stuff/DU/COMP4581/Assignment2/securities.csv')

# %%
prices.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
prices.nunique()
# Out:
# date        1762
# symbol       501
# open       97522
# close      98520
# low        97470
# high       97784
# volume    171073
# dtype: int64

# %%
securities.head()
# Out:
#   Ticker symbol             Security SEC filings             GICS Sector  \
# 0           MMM           3M Company     reports             Industrials
# 1           ABT  Abbott Laboratories     reports             Health Care
# 2          ABBV               AbbVie     reports             Health Care
# 3           ACN        Accenture plc     reports  Information Technology
# 4          ATVI  Activision Blizzard     reports  Information Technology
#
#                 GICS Sub Industry   Address of Headquarters Date first added  \
# 0        Industrial Conglomerates       St. Paul, Minnesota              NaN
# 1           Health Care Equipment   North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals   North Chicago, Illinois       2012-12-31
# 3  IT Consulting & Other Services           Dublin, Ireland       2011-07-06
# 4     Home Entertainment Software  Santa Monica, California       2015-08-31
#
#        CIK
# 0    66740
# 1     1800
# 2  1551152
# 3  1467373
# ...

# %%
securities['Ticker symbol'].nunique()
# Out:
# 505

# %%
    prices['change'] = prices.close.diff()
    prices.fillna(value=0, inplace=True)
    #change = OrderedDict(zip(prices.date, prices.change))

# %%
prices.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume    change
# 0  2163600.0  0.000000
# 1  2386400.0 -5.859993
# 2  2489500.0 -5.030006
# 3  2006300.0  1.670006
# 4  1408600.0 -1.650002

# %%
combined = pd.merge(securities[['Ticker symbol', 'Security']], prices, left_on='Ticker symbol', right_on='symbol' )

# %%
combined.head()
# Out:
#   Ticker symbol    Security        date symbol       open      close  \
# 0           MMM  3M Company  2010-01-04    MMM  83.089996  83.019997
# 1           MMM  3M Company  2010-01-05    MMM  82.800003  82.500000
# 2           MMM  3M Company  2010-01-06    MMM  83.879997  83.669998
# 3           MMM  3M Company  2010-01-07    MMM  83.320000  83.730003
# 4           MMM  3M Company  2010-01-08    MMM  83.690002  84.320000
#
#          low       high     volume     change
# 0  82.669998  83.449997  3043700.0  61.149996
# 1  81.699997  83.230003  2847000.0  61.160000
# 2  83.510002  84.599998  5268500.0  61.679998
# 3  82.120003  83.760002  4470100.0  61.460003
# 4  83.300003  84.320000  3405800.0  62.160000

# %%
combined['Ticker symbol'].value_counts()
# Out:
# MMM     1762
# PVH     1762
# OMC     1762
# OXY     1762
# ORLY    1762
#         ...
# KHC      378
# HPE      304
# CSRA     284
# WLTW     251
# FTV      126
# Name: Ticker symbol, Length: 501, dtype: int64

# %%
combined.nunique()
# Out:
# Ticker symbol       501
# Security            501
# date               1762
# symbol              501
# open              97522
# close             98520
# low               97470
# high              97784
# volume           171073
# change           474123
# dtype: int64

# %%
tickers = combined['Ticker symbol'].unique().tolist()
securities = combined['Security'].unique().tolist()
companies = [tickers, securities]

# %%
len(tickersSecurities[0])
# Out:
# 501

# %%
changesDates = combined[combined['Ticker symbol'] == 'AAPL'][['change', 'date']].values.tolist()
changesDates
# Out:
# [[-9.8071441429, '2010-01-04'],
#  [-9.514285714300001, '2010-01-05'],
#  [-10.351431285699999, '2010-01-06'],
#  [-10.397142857199999, '2010-01-07'],
#  [-10.357141142900002, '2010-01-08'],
#  [-10.224287285699997, '2010-01-11'],
#  [-9.865715142899997, '2010-01-12'],
#  [-9.997142571500003, '2010-01-13'],
#  [-9.641429571499998, '2010-01-14'],
#  [-9.891429571499998, '2010-01-15'],
#  [-8.780000714300002, '2010-01-19'],
#  [-8.912857142899998, '2010-01-20'],
#  [-9.505714857199997, '2010-01-21'],
#  [-11.490001999999997, '2010-01-22'],
#  [-11.489999714300001, '2010-01-25'],
#  [-11.1299988572, '2010-01-26'],
#  [-10.892856428600002, '2010-01-27'],
#  [-11.300000714300005, '2010-01-28'],
#  [-12.0128577143, '2010-01-29'],
#  [-12.671430857199997, '2010-02-01'],
#  [-13.2099994286, '2010-02-02'],
#  [-12.7285712857, '2010-02-03'],
#  [-13.494285285699998, '2010-02-04'],
#  [-12.797143714300002, '2010-02-05'],
#  [-13.078572857200001, '2010-02-08'],
# ...

# %%
stocks = {}

# %%
for i in range(len(tickersSecurities[0])):
    ticker = tickersSecurities[0][i]
    change = combined[combined['Ticker symbol'] == ticker]['change'].to_list()
    dates = combined[combined['Ticker symbol'] == ticker]['date'].to_list()
    stocks[tickersSecurities[0][i]] = [tickersSecurities[1][i], change, dates]

# %%
print(stocks['AAPL'])
# Out:
# ['Apple Inc.', [-9.8071441429, -9.514285714300001, -10.351431285699999, -10.397142857199999, -10.357141142900002, -10.224287285699997, -9.865715142899997, -9.997142571500003, -9.641429571499998, -9.891429571499998, -8.780000714300002, -8.912857142899998, -9.505714857199997, -11.490001999999997, -11.489999714300001, -11.1299988572, -10.892856428600002, -11.300000714300005, -12.0128577143, -12.671430857199997, -13.2099994286, -12.7285712857, -13.494285285699998, -12.797143714300002, -13.078572857200001, -13.5428565715, -14.455715285700002, -14.1685712857, -14.184287714299998, -13.5728587143, -13.944286285699999, -11.1600022857, -11.1900005715, -11.608574285699998, -12.068572714300004, -11.794284714300005, -11.872856571499998, -11.568570857200001, -11.444284142899999, -11.504285714300003, -11.585716571499997, -11.678569999999997, -11.011428857199995, -10.802855999999998, -10.0799984286, -10.010002, -10.1657141429, -9.808570571499999, -10.1028597143, -10.235713714299997, -10.332854714299
# ...
